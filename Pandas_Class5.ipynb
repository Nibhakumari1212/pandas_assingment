# %% [markdown]
# # 🐼 Pandas - Class 5: Sorting & Basic Statistics
# Welcome to **Class 5** of our Pandas series. Today we’ll learn how to sort data and calculate basic statistics.

# %% [markdown]
# ## 1. Sorting Data
# - Use `sort_values(by='col')` to sort by column values.
# - Use `ascending=False` for descending order.
# - Sort by multiple columns by passing a list.
# - `sort_index()` sorts by row or column index.

# %%
import pandas as pd
Data = {"Product":['Pen','Notebook','Pencil','Marker','Eraser','Sharpner'],
        "Price": [10,20,15,30,23,44],
        "Stock": [100,50,40,60,70,80],
        "Rating": [4.5,4.7,4.3,4.2,4.7,4.4]
        }

df = pd.DataFrame(Data)
df
#sort by a single column -> price
print(df.sort_values(by = 'Price'))

#sort  by a single colummn-> rating
print(df.sort_values(by = 'Rating',ascending =False ))

#sort by multiple columnn
df.sort_values(by=['Price','Stock'])

#sort indexing -> in decending order.
df.sort_index(ascending=False)
# Out:
#     Product  Price  Stock  Rating
# 0       Pen     10    100     4.5
# 2    Pencil     15     40     4.3
# 1  Notebook     20     50     4.7
# 4    Eraser     23     70     4.7
# 3    Marker     30     60     4.2
# 5  Sharpner     44     80     4.4
#     Product  Price  Stock  Rating
# 1  Notebook     20     50     4.7
# 4    Eraser     23     70     4.7
# 0       Pen     10    100     4.5
# 5  Sharpner     44     80     4.4
# 2    Pencil     15     40     4.3
# 3    Marker     30     60     4.2
#     Product  Price  Stock  Rating
# 5  Sharpner     44     80     4.4
# 4    Eraser     23     70     4.7
# 3    Marker     30     60     4.2
# 2    Pencil     15     40     4.3
# 1  Notebook     20     50     4.7
# 0       Pen     10    100     4.5

# %% [markdown]
# ## 2. Descriptive Statistics
# - `mean()`, `median()`, `mode()` for central tendency.
# - `std()` for standard deviation.
# - `describe()` for a summary of stats (count, mean, std, min, quartiles, max).

# %%
print(df)

# 1 mean of numberic column only
df.mean(numeric_only=True)

# 2 medain
df.median(numeric_only=True)

# 3 mode
print(df.mode())

# 4 Standard Deviation
print(df.std(numeric_only=True))

# 5 complete Statistical values of column
print(df.describe())
# Out:
#     Product  Price  Stock  Rating
# 0       Pen     10    100     4.5
# 1  Notebook     20     50     4.7
# 2    Pencil     15     40     4.3
# 3    Marker     30     60     4.2
# 4    Eraser     23     70     4.7
# 5  Sharpner     44     80     4.4
#     Product  Price  Stock  Rating
# 0    Eraser     10     40     4.7
# 1    Marker     15     50     NaN
# 2  Notebook     20     60     NaN
# 3       Pen     23     70     NaN
# 4    Pencil     30     80     NaN
# 5  Sharpner     44    100     NaN
# Price     12.077527
# Stock     21.602469
# Rating     0.206559
# dtype: float64
#            Price       Stock    Rating
# count   6.000000    6.000000  6.000000
# mean   23.666667   66.666667  4.466667
# std    12.077527   21.602469  0.206559
# min    10.000000   40.000000  4.200000
# 25%    16.250000   52.500000  4.325000
# 50%    21.500000   65.000000  4.450000
# 75%    28.250000   77.500000  4.650000
# max    44.000000  100.000000  4.700000

# %% [markdown]
# ## 3. Counting Values
# - `value_counts()` shows the frequency of unique values in a Series.
# - Use `normalize=True` to see percentages instead of counts.

# %%
import pandas as pd
Data = {"Product":['Pen','Notebook','Pencil','Marker','Eraser','Sharpner'],
        "Price": [10,20,15,30,23,44],
        "Stock": [100,50,40,60,70,80],
        "Rating": [4.5,4.7,4.3,4.2,4.7,4.4]
        }

df = pd.DataFrame(Data)
df
# 1 Count how many times each product appers
print(df['Product'].value_counts())

# 2 show percentage instead of counts
print(df['Product'].value_counts(normalize=True))

# 3 count values for columns rating
print(df['Rating'].value_counts())
# Out:
# Product
# Pen         1
# Notebook    1
# Pencil      1
# Marker      1
# Eraser      1
# Sharpner    1
# Name: count, dtype: int64
# Product
# Pen         0.166667
# Notebook    0.166667
# Pencil      0.166667
# Marker      0.166667
# Eraser      0.166667
# Sharpner    0.166667
# Name: proportion, dtype: float64
# Rating
# 4.7    2
# 4.5    1
# 4.3    1
# 4.2    1
# 4.4    1
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Correlation & Covariance
# - `corr()` computes correlation between numeric columns.
# - `cov()` computes covariance.
# - Correlation values range from -1 (negative) to +1 (positive).

# %%
# 1 correlation between all numberic columns
print(df.corr(numeric_only=True))

# -ve correlation -> one increases 2nd decrease
# +ve correlation -> one increases other increase

#2 correlation between all numberic columns
print(df.cov(numeric_only=True))

#3 correlation between 2 specific columns
df["Price"].corr(df['Stock'])
# Out:
#            Price     Stock    Rating
# Price   1.000000  0.048549 -0.245852
# Stock   0.048549  1.000000  0.149404
# Rating -0.245852  0.149404  1.000000
#              Price       Stock    Rating
# Price   145.866667   12.666667 -0.613333
# Stock    12.666667  466.666667  0.666667
# Rating   -0.613333    0.666667  0.042667
# np.float64(0.04854907079178099)

# %% [markdown]
# ## Mini Practice
# 1. Build a DataFrame with columns: Name, Age, Score, Height.
# 2. Sort the data by Score (descending).
# 3. Get mean, median, mode, and std of numeric columns.
# 4. Use value_counts on Name or any categorical column.
# 5. Compute corr() and cov() for all numeric columns.

# %%
# Write your mini practice solution here

# 1. Build a DataFrame with columns: Name, Age, Score, Height
import pandas as pd
d = {
    "Name":['Alice', 'Bob', 'Emma', 'Alex'],
    "Age":[21,19,16,23],
    "Score":[98,65,89,70],
    "Height":[5.3,4.9,5.8,5.5]
        }

df = pd.DataFrame(d)
df
# 2. Sort the data by Score (descending)
# Write your code here
print(df.sort_values(by="Score", ascending=False))

# 3. Get mean, median, mode, and std of numeric columns
# Write your
print(df.mean(numeric_only=True))

# Median
print(df.median(numeric_only=True))

# Mode
print(df.mode(numeric_only=True))

# Standard Deviation
print(df.std(numeric_only=True))


# 4. Use value_counts on Name or any categorical column
# Write your code here
print(df["Name"].value_counts())


# 5. Compute corr() and cov() for all numeric columns
# Write your code here
print(df.corr(numeric_only=True))

print(df.cov(numeric_only=True))
# Out:
#     Name  Age  Score  Height
# 0  Alice   21     98     5.3
# 2   Emma   16     89     5.8
# 3   Alex   23     70     5.5
# 1    Bob   19     65     4.9
# Age       20.0
# Score     79.5
# Height     5.4
# dtype: float64
#    Age  Score  Height
# 0   16     65     4.9
# 1   19     70     5.3
# 2   21     89     5.5
# 3   23     98     5.8
# Age        2.986079
# Score     15.588457
# Height     0.377492
# dtype: float64
# Age       19.750
# Score     80.500
# Height     5.375
# dtype: float64
# Name
# Alice    1
# Bob      1
# Emma     1
# Alex     1
# Name: count, dtype: int64
#              Age     Score    Height
# Age     1.000000 -0.232733 -0.273534
# Score  -0.232733  1.000000  0.472993
# Height -0.273534  0.472993  1.000000
#               Age       Score    Height
# Age      8.916667  -10.833333 -0.308333
# Score  -10.833333  243.000000  2.783333
# Height  -0.308333    2.783333  0.142500

# %% [markdown]
# ---
# ## Summary
# - Learned to sort by columns with `sort_values` and by index with `sort_index`.
# - Explored descriptive statistics: mean, median, mode, std, describe.
# - Counted values with `value_counts`.
# - Calculated correlation and covariance.
