# %% [markdown]
# # 🐼 Pandas - Class 2: DataFrame Basics
# Welcome to **Class 2**. Today we’ll learn how to **inspect**, **select**, and **organize** data inside a DataFrame.

# %% [markdown]
# ## 1 Inspecting Data
# Quick ways to understand your dataset:
# - `head(n)` → first *n* rows (default 5)
# - `tail(n)` → last *n* rows
# - `info()` → columns, non-null counts, and dtypes
# - `shape` → (rows, columns)
# - `dtypes` → data type of each column

# %%
import pandas as pd

# Create a small DataFrame
a = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [25, 30, 35, 40, 22],
    "Score": [88, 92, 79, 85, 95]
}

b = pd.DataFrame(a)
print(b)


#1 .head()-> by deafault gives you starting 5 rows
print(b.head())
print(b.head(2))

#2 .tail -> by deafaault gives you last 2 rows
print(b.tail(2))

#3 .info()
print(b.info())

#4 .shape -> shape will gives you no of rows and columns
print(b.shape)

#5 .dtypes -> data type columns
print(b.dtypes)
# Out:
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
#     Name  Age  Score
# 0  Alice   25     88
# 1    Bob   30     92
#     Name  Age  Score
# 3  David   40     85
# 4   Emma   22     95
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   Score   5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes
# None
# (5, 3)
# Name     object
# Age       int64
# Score     int64
# dtype: object

# %% [markdown]
# ## 2 Selecting Columns & Rows
# Ways to access parts of a DataFrame:
# - Single column → `df['col']`
# - Multiple columns → `df[['col1','col2']]`
# - Label-based selection → `df.loc[row_label, col_label]`
# - Integer-index selection → `df.iloc[row_idx, col_idx]`
# Tip: `:` means "all rows/columns" in that dimension.

# %%
print(b)
# single column
print(b['Age'])

# multiple columns
print(b[['Age','Score']])

# lable-based selection
print(b.loc[2,'Score'])
print(b.loc[2,['Score','Age','Name','Age']])
# selecting using iloc index by silicing
print(b.iloc[0:3,0:2])
# Out:
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
# 0    25
# 1    30
# 2    35
# 3    40
# 4    22
# Name: Age, dtype: int64
#    Age  Score
# 0   25     88
# 1   30     92
# 2   35     79
# 3   40     85
# 4   22     95
# 79
# Score         79
# Age           35
# Name     Charlie
# Age           35
# Name: 2, dtype: object
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %% [markdown]
# ## 3 Index & Columns Overview
# - `df.index` → row labels
# - `df.columns` → column names
# - `df.values` → underlying NumPy array (read-only; prefer using DataFrame ops)

# %%
#1 .index -> row start stop and step
print(b.index)

#2 .columns -> name of the columns
print(b.columns)

#3 .values -> dataframe converts into matrix it gives you values of rows
print(b.values)
# Out:
# RangeIndex(start=0, stop=5, step=1)
# Index(['Name', 'Age', 'Score'], dtype='object')
# [['Alice' 25 88]
#  ['Bob' 30 92]
#  ['Charlie' 35 79]
#  ['David' 40 85]
#  ['Emma' 22 95]]

# %% [markdown]
# ## 4 Renaming Columns & Setting an Index
# - Rename columns → `df.rename(columns={'old':'new'}, inplace=False)`
# - Set a column as index → `df.set_index('column_name', inplace=False)`
# - Reset index → `df.reset_index(inplace=False)`
#  If you don't use `inplace=True`, remember to assign the result back to a variable.

# %%
print(b)
#rename
b.rename(columns={'Name':'Naam'}, inplace= False)
print(b)
b.rename(columns={'Name':'Naam'}, inplace= True)
print(b)
#set index
c = b.set_index("Naam")
print(c)
#reset
c.reset_index(inplace=True)
print(c)
print(b)
# Out:
#       Naam  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
#       Naam  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
#       Naam  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
#          Age  Score
# Naam
# Alice     25     88
# Bob       30     92
# Charlie   35     79
# David     40     85
# Emma      22     95
#       Naam  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
#       Naam  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95

# %% [markdown]
# ## 5 Basic Attributes Recap
# - `df.columns` → names of all columns
# - `df.index` → row labels
# - `df.values` → NumPy array (data only)
# These are handy for quick checks and loops (though vectorized ops are preferred).

# %%
import pandas as pd
d = {
    "Name":["Raj", "Ankit", "Sanju", "Poonam"], 
    "Age":[23,21,26,27],
    "Marks":[90,98,97,96]
}
b = pd.DataFrame(d)
print(b.columns)
print(b.index)
print(b.values)
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')
# RangeIndex(start=0, stop=4, step=1)
# [['Raj' 23 90]
#  ['Ankit' 21 98]
#  ['Sanju' 26 97]
#  ['Poonam' 27 96]]

# %% [markdown]
# ##Mini Practice
# 1. Create a DataFrame with at least 5 rows and 4 columns (mix of numeric + text).
# 2. Show the first 3 rows, last 2 rows, and the info.
# 3. Select a sub-DataFrame with only 2 columns.
# 4. Rename one column and set any column as index, then reset it back.
# 5. Print `df.shape`, `df.dtypes`, and `df.columns`.

# %%
import pandas as pd

# Create a DataFrame with at least 5 rows & 4 columns (mix of numbers + text)
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [25, 30, 35, 40, 22],
    "City": ["Delhi", "Mumbai", "Pune", "Bangalore", "Chennai"],
    "Score": [85, 91, 78, 88, 95]
}

df = pd.DataFrame(data)
print(df)

# Show the first 3 rows, last 2 rows, and info
# Show the first 3 rows
print("\n ----First 3 rows---")
print(df.head(3))

# Show the last 2 rows
print("\n ----Last 2 rows----")
print(df.tail(2))

# Show the DataFrame info
print("\n ----DataFrame info----")
df.info()


# Select a sub-DataFrame with only 2 columns
# your code here
# Select only 'Name' and 'Score' columns
sub_df = df[["Name", "Score"]]
sub_df


#Rename one col and set any col use index, then reset it back
# your code here
#rename a columns
df.rename(columns={"Score":"Marks"},inplace=True)
print(df)
#set name as index

c = df.set_index("Name")
print(df)
#reset index back
df.reset_index(inplace=True)
print(c)
print(df)
#print df.shape,df.dtypes, df.columns
print(df.shape)
print(df.dtypes)
print(df.columns)
# Out:
#       Name  Age       City  Score
# 0    Alice   25      Delhi     85
# 1      Bob   30     Mumbai     91
# 2  Charlie   35       Pune     78
# 3    David   40  Bangalore     88
# 4     Emma   22    Chennai     95
#
#  ----First 3 rows---
#       Name  Age    City  Score
# 0    Alice   25   Delhi     85
# 1      Bob   30  Mumbai     91
# 2  Charlie   35    Pune     78
#
#  ----Last 2 rows----
#     Name  Age       City  Score
# 3  David   40  Bangalore     88
# 4   Emma   22    Chennai     95
#
#  ----DataFrame info----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   City    5 non-null      object
#  3   Score   5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
#       Name  Age       City  Marks
# 0    Alice   25      Delhi     85
# 1      Bob   30     Mumbai     91
# 2  Charlie   35       Pune     78
# 3    David   40  Bangalore     88
# 4     Emma   22    Chennai     95
#       Name  Age       City  Marks
# 0    Alice   25      Delhi     85
# 1      Bob   30     Mumbai     91
# 2  Charlie   35       Pune     78
# 3    David   40  Bangalore     88
# 4     Emma   22    Chennai     95
#          Age       City  Marks
# Name
# Alice     25      Delhi     85
# Bob       30     Mumbai     91
# Charlie   35       Pune     78
# David     40  Bangalore     88
# Emma      22    Chennai     95
#    index     Name  Age       City  Marks
# 0      0    Alice   25      Delhi     85
# 1      1      Bob   30     Mumbai     91
# 2      2  Charlie   35       Pune     78
# 3      3    David   40  Bangalore     88
# 4      4     Emma   22    Chennai     95
# (5, 5)
# index     int64
# Name     object
# Age       int64
# City     object
# Marks     int64
# dtype: object
# Index(['index', 'Name', 'Age', 'City', 'Marks'], dtype='object')

# %% [markdown]
# ---
# ## ✅ Summary
# - You learned to **inspect** a DataFrame (`head`, `tail`, `info`, `shape`, `dtypes`).
# - You practiced **selecting** columns/rows using `[]`, `.loc`, and `.iloc`.
# - You explored **index/columns** and basic attributes.
# - You **renamed** columns and **set/reset** an index.
#
# Next up: **Data Cleaning Essentials** (missing values, types, duplicates).
