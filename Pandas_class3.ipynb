# %% [markdown]
# # 🐼 Pandas - Class 3: Data Cleaning Essentials
# Welcome to **Class 3** of our Pandas series. Today we’ll learn how to clean and prepare data for analysis.

# %% [markdown]
# ## Handling Missing Values
# Real-world datasets often have missing data. Pandas offers:
# - `isna()` / `isnull()` → detect missing values (returns True/False)
# - `dropna()` → remove missing values (rows/columns)
# - `fillna()` → replace missing values with a given value or method (e.g., forward fill)
#
# Always inspect how much data is missing before deciding to drop or fill.

# %%
import pandas as pd 
import numpy as np 
a = {
    "Name": ["Alice", None, "Charlie", "David", "Emma"],
    "Age": [25, None, 35, 40, None],
    "City": ["Delhi", "Mumbai", None, "Bangalore", "Chennai"],
    "Score": [85, 91, np.nan, 88, 95]
}

b = pd.DataFrame(a)
# 1 isna()-> null values -> marks True
print(b.isna())

# 2 isnull()
print(b.isnull())
print(b.isnull().sum())# columns wise null values

# 3 dropna() -> removes the rows which have null values
print(b)
print(b.dropna())

# 4 fillna() ->
print(b)
b['Age'].fillna(b['Age'].mean(),inplace=True)
b['Score'].fillna(0,inplace=True)
print(b)

b['City'].fillna('unknown', inplace=True)
print(b)
# Out:
#     Name    Age   City  Score
# 0  False  False  False  False
# 1   True   True  False  False
# 2  False  False   True   True
# 3  False  False  False  False
# 4  False   True  False  False
#     Name    Age   City  Score
# 0  False  False  False  False
# 1   True   True  False  False
# 2  False  False   True   True
# 3  False  False  False  False
# 4  False   True  False  False
# Name     1
# Age      2
# City     1
# Score    1
# dtype: int64
#       Name   Age       City  Score
# 0    Alice  25.0      Delhi   85.0
# 1     None   NaN     Mumbai   91.0
# 2  Charlie  35.0       None    NaN
# 3    David  40.0  Bangalore   88.0
# 4     Emma   NaN    Chennai   95.0
#     Name   Age       City  Score
# 0  Alice  25.0      Delhi   85.0
# 3  David  40.0  Bangalore   88.0
#       Name   Age       City  Score
# 0    Alice  25.0      Delhi   85.0
# 1     None   NaN     Mumbai   91.0
# 2  Charlie  35.0       None    NaN
# 3    David  40.0  Bangalore   88.0
# 4     Emma   NaN    Chennai   95.0
#       Name        Age       City  Score
# 0    Alice  25.000000      Delhi   85.0
# 1     None  33.333333     Mumbai   91.0
# 2  Charlie  35.000000       None    0.0
# 3    David  40.000000  Bangalore   88.0
# 4     Emma  33.333333    Chennai   95.0
#       Name        Age       City  Score
# 0    Alice  25.000000      Delhi   85.0
# 1     None  33.333333     Mumbai   91.0
# 2  Charlie  35.000000       None    0.0
# 3    David  40.000000  Bangalore   88.0
# 4     Emma  33.333333    Chennai   95.0
# C:\Users\MSI THIN 15\AppData\Local\Temp\ipykernel_13236\2406668067.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   b['Age'].fillna(b['Age'].mean(),inplace=True)
# C:\Users\MSI THIN 15\AppData\Local\Temp\ipykernel_13236\2406668067.py:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   b['Score'].fillna(0,inplace=True)

# %% [markdown]
# ## Changing Data Types (`astype`)
# - Convert a column to a different type using `astype()`.
# - Examples: converting strings to numbers, integers to floats, or columns to category.
#
# Be careful: make sure the data is compatible with the new type!

# %%
a = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [25, 30, 35, 40, 22],
    "Score": [88, 92, 79, 85, 95]
}

b = pd.DataFrame(a)

b['Age'].astype(float)
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    40.0
# 4    22.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Replacing Values (`replace`)
# - Use `replace()` to substitute specific values or patterns.
# - Useful for cleaning labels, fixing typos, or mapping categories.

# %%
print(b)
b['Name'].replace('Alice',"Alex",inplace=True)
print(b)
# Out:
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
#       Name  Age  Score
# 0     Alex   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
# C:\Users\MSI THIN 15\AppData\Local\Temp\ipykernel_8248\3020067177.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   b['Name'].replace('Alice',"Alex",inplace=True)

# %% [markdown]
# ## Dropping Rows & Columns (`drop`)
# - `drop(labels, axis=0)` → drop rows by index labels.
# - `drop(labels, axis=1)` → drop columns by name.
# - Use `inplace=True` if you want to modify the DataFrame directly.

# %%
import pandas as pd 
import numpy as np 
a = {
    "Name": ["Alice", None, "Charlie", "David", "Emma"],
    "Age": [25, None, 35, 40, None],
    "City": ["Delhi", "Mumbai", None, "Bangalore", "Chennai"],
    "Score": [85, 91, np.nan, 88, 95]
}

b = pd.DataFrame(a)
b
#print(b.drop(index = 2,axis = 0,inplace=True))
#print(b.drop(index = 2,axis = 1,inplace=True))
# Out:
#     Name   Age       City  Score
# 0  Alice  25.0      Delhi   85.0
# 1   None   NaN     Mumbai   91.0
# 3  David  40.0  Bangalore   88.0
# 4   Emma   NaN    Chennai   95.0
#     Name   Age       City  Score
# 0  Alice  25.0      Delhi   85.0
# 1   None   NaN     Mumbai   91.0
# 3  David  40.0  Bangalore   88.0
# 4   Emma   NaN    Chennai   95.0

# %% [markdown]
# ## Detecting & Removing Duplicates
# - `duplicated()` → returns a Boolean Series marking duplicate rows.
# - `drop_duplicates()` → remove duplicate rows.
# - You can specify `subset` (columns) and `keep` ('first', 'last', or False).

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "Alice", "Bob", "David"],
    "Age": [25, 30, 35, 25, 30, 40],
    "Score": [88, 92, 79, 88, 92, 85]
}

df = pd.DataFrame(data)
df.duplicated()
df.duplicated().sum()
df.drop_duplicates(inplace=True,keep = 'first')
print(df)
# Out:
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 5    David   40     85

# %% [markdown]
# ## Mini Practice
# 1. Create a messy DataFrame with missing values, wrong data types, typos, extra columns, and duplicates.
# 2. Clean it step-by-step using what you learned:
#    - Handle missing values
#    - Change data types
#    - Replace incorrect values
#    - Drop unnecessary rows/columns
#    - Remove duplicates

# %%
import pandas as pd
import numpy as np
# 1. Create a messy DataFrame
data = {
    "Name": ["Alice", "Bob", "Chrlie", "David", "Alice", None],
    "Age": ["25", "30", None, "40", "25", "30"],      # ages stored as strings, with missing value
    "City": ["Delhi", "Mumbai", "Pun", "Bangalore", "Delhi", "Mumbai"],  # typo: "Pun" -> "Pune"
    "Score": [85, None, 78, 88, 85, 91],              
    "Extra": ["x", "y", "z", "x", "y", "z"]           
}
df = pd.DataFrame(data)
print(df)
# 2. Handle missing values
# Fill or drop as needed

# Remove rows where Name is missing
print(df.dropna(subset=["Name"],inplace = True))

# Fill missing Score with 0 (or another suitable value)
df['Score'].fillna(0,inplace= True)

print(df)

# 3. Change data types
# Convert Age to int, Score to float, etc.
df["Age"].fillna(0,inplace = True)
df["Score"].fillna(0,inplace = True)
print(df)

# Change data types
df["Age"].astype(int)
df["Score"].astype(float)
print(df.dtypes)



# 4. Replace incorrect values
# Fix 'Pun' -> 'Pune', maybe unify Name spellings if needed
print(df["City"].replace("Pun", "Pune",inplace = True))

# 5. Drop unnecessary rows/columns
# Remove 'Extra' or any row you don't want
print(df.drop(columns=['Extra'],inplace = True))


# 6. Remove duplicates
# Use duplicated() and drop_duplicates()
print(df.drop_duplicates(subset=["Name"], inplace=True, keep="last"))


# 7. Final clean DataFrame
# Print the cleaned DataFrame and check info()
# Final cleaned DataFrame
print("Final Cleaned DataFrame:")
print(df)
# Check data information
#print("\nDataFrame Info:")
print("\nDataFrame Info:")
df.info()
# Out:
#      Name   Age       City  Score Extra
# 0   Alice    25      Delhi   85.0     x
# 1     Bob    30     Mumbai    NaN     y
# 2  Chrlie  None        Pun   78.0     z
# 3   David    40  Bangalore   88.0     x
# 4   Alice    25      Delhi   85.0     y
# 5    None    30     Mumbai   91.0     z
# None
#      Name   Age       City  Score Extra
# 0   Alice    25      Delhi   85.0     x
# 1     Bob    30     Mumbai    0.0     y
# 2  Chrlie  None        Pun   78.0     z
# 3   David    40  Bangalore   88.0     x
# 4   Alice    25      Delhi   85.0     y
#      Name Age       City  Score Extra
# 0   Alice  25      Delhi   85.0     x
# 1     Bob  30     Mumbai    0.0     y
# 2  Chrlie   0        Pun   78.0     z
# 3   David  40  Bangalore   88.0     x
# 4   Alice  25      Delhi   85.0     y
# Name      object
# Age       object
# City      object
# Score    float64
# Extra     object
# dtype: object
# None
# None
# None
# Final Cleaned DataFrame:
#      Name Age       City  Score
# 1     Bob  30     Mumbai    0.0
# 2  Chrlie   0       Pune   78.0
# 3   David  40  Bangalore   88.0
# 4   Alice  25      Delhi   85.0
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 1 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      object
#  2   City    4 non-null      object
#  3   Score   4 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 160.0+ bytes
# C:\Users\MSI THIN 15\AppData\Local\Temp\ipykernel_34108\3707730189.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Score'].fillna(0,inplace= True)
# C:\Users\MSI THIN 15\AppData\Local\Temp\ipykernel_34108\3707730189.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(0,inplace = True)
# C:\Users\MSI THIN 15\AppData\Local\Temp\ipykernel_34108\3707730189.py:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Score"].fillna(0,inplace = True)
# C:\Users\MSI THIN 15\AppData\Local\Temp\ipykernel_34108\3707730189.py:39: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   print(df["City"].replace("Pun", "Pune",inplace = True))

# %%
import pandas as pd
import numpy as np
# 1. Create a messy DataFrame
data = {
    "Name": ["Alice", "Bob", "Chrlie", "David", "Alice", None],
    "Age": ["25", "30", None, "40", "25", "30"],      # ages stored as strings, with missing value
    "City": ["Delhi", "Mumbai", "Pun", "Bangalore", "Delhi", "Mumbai"],  # typo: "Pun" -> "Pune"
    "Score": [85, None, 78, 88, 85, 91],              
    "Extra": ["x", "y", "z", "x", "y", "z"]           
}
df = pd.DataFrame(data)
print(df)
# 2. Handle missing values
# Fill or drop as needed

# Remove rows where Name is missing
df.dropna(subset=["Name"],inplace = True)

# Fill missing Score with 0 (or another suitable value)
df['Score'].fillna(0,inplace= True)

print(df)

# 3. Change data types
# Convert Age to int, Score to float, etc.


# Change data types



# 4. Replace incorrect values
# Fix 'Pun' -> 'Pune', maybe unify Name spellings if needed

# 5. Drop unnecessary rows/columns
# Remove 'Extra' or any row you don't want


# 6. Remove duplicates
# Use duplicated() and drop_duplicates()


# 7. Final clean DataFrame
# Print the cleaned DataFrame and check info()
# Final cleaned DataFrame


# Check data information
#print("\nDataFrame Info:")

# %% [markdown]
# ---
# ## Summary
# - Learned to handle missing values (`isna`, `dropna`, `fillna`).
# - Converted column data types with `astype`.
# - Cleaned up incorrect entries with `replace`.
# - Removed unwanted rows/columns with `drop`.
# - Detected and removed duplicates.
